# %% [markdown]
# # Dữ liệu dulieuxettuyendaihoc.csv được mô tả như sau

# %% [markdown]
# Dữ liệu lưu trữ điểm trung bình môn, khu vực, khối thi và điểm thi đại học của 100 học sinh. -
# T1, L1, H1, S1, V1, X1, D1, N1 lần lượt là điểm trung bình các môn Toán, Lý ,Hóa,
# Sinh, Văn, Sử, Địa, Ngoại ngữ năm lớp 10 - - - - - -
# T2, L2, H2, S2, V2, X2, D2, N2 lần lượt là điểm trung bình các môn Toán, Lý ,Hóa,
# Sinh, Văn, Sử, Địa, Ngoại ngữ năm lớp 11
# T6, L6, H6, S6, V6, X6, D6, N6 lần lượt là điểm trung bình các môn Toán, Lý ,Hóa,
# Sinh, Văn, Sử, Địa, Ngoại ngữ năm lớp 12
# GT: Giới tính
# DT: Dân tộc
# KV, KT lần lượt là khu vực thi và khối thi
# DH1, DH2, DH3 lần lượt là điểm thi đại học môn 1, môn 2, môn 3
# Sử dụng Pandas  để thực hiện các yêu cầu sau đây

# %% [markdown]
# # 1. Xác định và phân loại dữ liệu định tính và định lượng

# %%
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

# Phân loại
dinh_tinh = ['GT', 'DT', 'KV', 'KT']
dinh_luong = [col for col in df.columns if col not in dinh_tinh]

print("Dữ liệu định tính:", dinh_tinh)
print("Dữ liệu định lượng:", dinh_luong)

# %% [markdown]
# # 2. Định nghĩa các thang đo phù hợp cho từng biến số

# %%
import pandas as pd

# Đọc dữ liệu
df = pd.read_csv("dulieuxettuyendaihoc.csv")
# Khai báo thang đo
nominal = ['GT', 'DT', 'KT']
ordinal = ['KV']

# Tạo bảng thang đo
scale_df = pd.DataFrame({
    'Biến': df.columns,
    'Thang đo': [
        'Nominal' if col in nominal else
        'Ordinal' if col in ordinal else
        'Ratio'
        for col in df.columns
    ]
})

print(scale_df)

print(scale_df)

# %% [markdown]
# # 3. Sử dụng Python để tải dữ liệu lên chương trình và in ra màn hình 10 dòng đầu tiên và 10 dòng cuối cùng

# %%
import pandas as pd

# Tải dữ liệu
df = pd.read_csv("dulieuxettuyendaihoc.csv")

# In 10 dòng đầu
print("=== 10 dòng đầu ===")
print(df.head(10))

# In 10 dòng cuối
print("\n=== 10 dòng cuối ===")
print(df.tail(10))

# %% [markdown]
# # 4. Thống kê dữ liệu thiếu cho cột dân tộc và hiệu chỉnh dữ liệu thiếu như sau: Mặc định thiếu thì điền giá trị 0.
# Hướng dẫn
# 1. Lập bảng tần số, tần suất để khảo sát dữ liệu thiếu, bao nhiêu dữ liệu riêng biệt (pandas
# unique)
# 2. Thực hiện thay thế dữ liệu thiếu bằng phương pháp điền dữ liệu 0

# %%
# 1. Khảo sát dữ liệu cột DT
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

# Kiểm tra giá trị unique
print("Các giá trị khác nhau trong DT:")
print(df['DT'].unique())

# Đếm tần số
tan_so = df['DT'].value_counts(dropna=False)

# Tính tần suất (%)
tan_suat = df['DT'].value_counts(normalize=True, dropna=False) * 100

# Gộp lại thành bảng
bang_thong_ke = pd.DataFrame({
    'Tần số': tan_so,
    'Tần suất (%)': tan_suat
})

print("\nBảng tần số - tần suất:")
print(bang_thong_ke)

# Đếm số giá trị thiếu
print("\nSố giá trị thiếu:", df['DT'].isnull().sum())

# 2. Xử lý dữ liệu thiếu (điền 0)
# Thay thế giá trị thiếu bằng 0
df['DT'] = df['DT'].fillna(0)

# Kiểm tra lại
print("Số giá trị thiếu sau khi xử lý:", df['DT'].isnull().sum())

print(df['DT'].value_counts(dropna=False))
# Out:
# Các giá trị khác nhau trong DT:
# [nan  1.  6.]
#
# Bảng tần số - tần suất:
#      Tần số  Tần suất (%)
# DT
# NaN      97          97.0
# 1.0       2           2.0
# 6.0       1           1.0
#
# Số giá trị thiếu: 97
# Số giá trị thiếu sau khi xử lý: 0
# DT
# 0.0    97
# 1.0     2
# 6.0     1
# Name: count, dtype: int64

# %% [markdown]
# # 5. Thống kê dữ liệu thiếu cho biến T1 và hiệu chỉnh dữ liệu, lưu ý việc thay thế dữ liệu thiếu sử dụng phương pháp Mean.
# Hướng dẫn
# 1. Lập bảng tần số, tần suất để khảo sát dữ liệu thiếu
# 2. Thực hiện thay thế dữ liệu thiếu bằng phương pháp Mean

# %%
# 1. Lập bảng tần số, tần suất để khảo sát dữ liệu thiếu
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

# Xem các giá trị khác nhau
print("Các giá trị trong T1:")
print(df['T1'].unique())

# Bảng tần số
tan_so = df['T1'].value_counts(dropna=False)

# Bảng tần suất (%)
tan_suat = df['T1'].value_counts(normalize=True, dropna=False) * 100

# Gộp bảng
bang_thong_ke = pd.DataFrame({
    'Tần số': tan_so,
    'Tần suất (%)': tan_suat
})

print("\nBảng tần số - tần suất:")
print(bang_thong_ke)

# Đếm số giá trị thiếu
print("\nSố giá trị thiếu:", df['T1'].isnull().sum())

# 2. Thực hiện thay thế dữ liệu thiếu bằng phương pháp Mean 
# Tính giá trị trung bình
mean_T1 = df['T1'].mean()

print("Giá trị trung bình T1:", mean_T1)

# Thay thế giá trị thiếu bằng mean
df['T1'] = df['T1'].fillna(mean_T1)

# Kiểm tra lại
print("Số giá trị thiếu sau xử lý:", df['T1'].isnull().sum())

# Kiểm tra lại phân bố sau khi xử lý
print(df['T1'].value_counts(dropna=False))

# %% [markdown]
# # 6. Hãy thực hiện xử lý lần lượt tất cả dữ liệu thiếu cho các biến về điểm số còn lại.

# %%
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

# Loại bỏ các biến định tính
categorical = ['GT', 'DT', 'KV', 'KT']

# Lấy các cột điểm
score_cols = [col for col in df.columns if col not in categorical]

print("Các cột điểm:")
print(score_cols)

missing_before = df[score_cols].isnull().sum()
print("Số giá trị thiếu trước khi xử lý:")
print(missing_before)

for col in score_cols:
    mean_value = df[col].mean()
    df[col] = df[col].fillna(mean_value)

missing_after = df[score_cols].isnull().sum()

print("Số giá trị thiếu sau khi xử lý:")
print(missing_after)

# %% [markdown]
# # 7. Tạo các biến TBM1, TBM2, TBM3 tương ứng với trung bình môn của các năm lớp 10, 11 và 12.
# • Công thức tính: TBM = (T*2 + L + H + S + V*2 + X + D + N) / 10

# %%
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

# TBM lớp 10
df['TBM1'] = (df['T1']*2 + df['L1'] + df['H1'] + df['S1'] +
              df['V1']*2 + df['X1'] + df['D1'] + df['N1']) / 10

# TBM lớp 11
df['TBM2'] = (df['T2']*2 + df['L2'] + df['H2'] + df['S2'] +
              df['V2']*2 + df['X2'] + df['D2'] + df['N2']) / 10

# TBM lớp 12
df['TBM3'] = (df['T6']*2 + df['L6'] + df['H6'] + df['S6'] +
              df['V6']*2 + df['X6'] + df['D6'] + df['N6']) / 10

# Xem kết quả
print(df[['TBM1', 'TBM2', 'TBM3']].head())

# %% [markdown]
# # 8. Tạo các biến xếp loại XL1, XL2 và XL3 dựa trên TBM1,TBM2 và TBM3 cho từng năm lớp 10, 11, 12 như sau:
# • Nhỏ hơn 5.0 xếp loại: yếu (kí hiệu là Y)
# • Từ 5.0 đến dưới 6.5: trung bình (kí hiệu là TB)
# • Từ 6.5 đến dưới 8.0: khá (kí hiệu là K)
# • Từ 8.0 đến dưới 9.0: giỏi (kí hiệu là G)
# • Từ 9.0 trở lên: xuất sắc (kí hiệu là XS)

# %%
# Hàm xếp loại
def xep_loai(tbm):
    if tbm < 5:
        return 'Y'
    elif tbm < 6.5:
        return 'TB'
    elif tbm < 8:
        return 'K'
    elif tbm < 9:
        return 'G'
    else:
        return 'XS'

# Áp dụng cho từng năm
df['XL1'] = df['TBM1'].apply(xep_loai)
df['XL2'] = df['TBM2'].apply(xep_loai)
df['XL3'] = df['TBM3'].apply(xep_loai)

# Xem kết quả
print(df[['TBM1','XL1','TBM2','XL2','TBM3','XL3']].head())

# %% [markdown]
# # 9. Tạo các biến US_TBM1, US_TBM2 và US_TBM3 để chuyển điểm trung bình các năm lớp 10, 11 và 12 từ thang điểm 10 của Việt Nam sang thang điểm 4 của Mỹ. Sử dụng phương pháp Min-Max Normalization

# %%
import pandas as pd

df = pd.read_csv("dulieuxettuyendaihoc.csv")

df['TBM1'] = (df['T1']*2 + df['L1'] + df['H1'] + df['S1'] + df['V1']*2 + df['X1'] + df['D1'] + df['N1']) / 10
df['TBM2'] = (df['T2']*2 + df['L2'] + df['H2'] + df['S2'] + df['V2']*2 + df['X2'] + df['D2'] + df['N2']) / 10
df['TBM3'] = (df['T6']*2 + df['L6'] + df['H6'] + df['S6'] + df['V6']*2 + df['X6'] + df['D6'] + df['N6']) / 10

# Chuẩn hóa từ thang 10 -> 4
df['US_TBM1'] = df['TBM1'] / 10 * 4
df['US_TBM2'] = df['TBM2'] / 10 * 4
df['US_TBM3'] = df['TBM3'] / 10 * 4

# Xem kết quả
print(df[['TBM1','US_TBM1','TBM2','US_TBM2','TBM3','US_TBM3']].head())

# %% [markdown]
# # 10. Tạo biến kết quả xét tuyển (kí hiệu là KQXT) nhằm xác định sinh viên đậu (giá trị “1”) và rớt ( giá trị “0”) vào các khối dựa trên điểm DH1, DH2 và DH3 như sau:
# • Với khối A, A1 nếu [(DH1*2 + DH2 + DH3)/4] lớn hơn hoặc bằng 5.0 thì đậu,
# ngược lại là rớt
# • Với khối B nếu [(DH1 + DH2*2 + DH3)/4] lớn hơn hoặc bằng 5.0 thì đậu, ngược
# lại là rớt
# • Với khối khác nếu [(DH1+ DH2 + DH3)/3] lớn hơn hoặc bằng 5.0 thì đậu, ngược
# lại là rớt

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("dulieuxettuyendaihoc.csv")

# Tính điểm xét tuyển theo từng khối
df['DIEM_XT'] = np.where(
    df['KT'].isin(['A', 'A1']),
    (df['DH1']*2 + df['DH2'] + df['DH3']) / 4,
    np.where(
        df['KT'] == 'B',
        (df['DH1'] + df['DH2']*2 + df['DH3']) / 4,
        (df['DH1'] + df['DH2'] + df['DH3']) / 3
    )
)

# Xét đậu / rớt
df['KQXT'] = np.where(df['DIEM_XT'] >= 5, 1, 0)

# Xem kết quả
print(df[['KT','DH1','DH2','DH3','DIEM_XT','KQXT']].head())

# %% [markdown]
# # 11. Lưu trữ dữ liệu xuống ổ đĩa thành file processed_dulieuxettuyendaihoc.csv

# %%
df.to_csv(r"D:\2274802010706-BÙI PHƯỚC MINH QUANG-THỰC HÀNH NHẬP MÔN PHÂN TÍCH DỮ LIỆU VÀ HỌC SÂU BUỔI 1\processed_dulieuxettuyendaihoc.csv", index=False)
